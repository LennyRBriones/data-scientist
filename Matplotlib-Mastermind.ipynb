# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline
#Permite dejar la gráfica presente en el notebook

# %% [markdown]
# # Estructura

# %% [markdown]
# ## Figura

# %%
fig = plt.figure(figsize=(1,1))
#cada 1 son 72 pixeles
plt.show() #No es necesario en nuestro caso, pero si hay que ponerlo para en caso de usar en otro IDE

# %% [markdown]
# ## Axes

# %%
# Silly example data
bp_x = np.linspace(0, 2*np.pi, num=40, endpoint=True)
bp_y = np.sin(bp_x)

# Make the plot
plt.plot(bp_x, bp_y, linewidth=3, linestyle="--",
         color="blue", label=r"Legend label $\sin(x)$")
plt.xlabel(r"Description of $x$ coordinate (units)")
plt.ylabel(r"Description of $y$ coordinate (units)")
plt.title(r"Title here (remove for papers)")
plt.xlim(0, 2*np.pi)
plt.ylim(-1.1, 1.1)
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# Podemos modificarlo

# %%
# Silly example data
bp_x = np.linspace(0, 2*np.pi, num=40, endpoint=True)
bp_y = np.sin(bp_x)

# Make the plot
fig = plt.figure(figsize=(10,6))
plt.plot(bp_x, bp_y, linewidth=3, linestyle="--",
         color="blue", label=r"Legend label $\sin(x)$")
plt.xlabel(r"Description of $x$ coordinate (units)")
plt.ylabel(r"Description of $y$ coordinate (units)")
plt.title(r"Title here (remove for papers)")
plt.xlim(0, 2*np.pi)
plt.ylim(-1.1, 1.1)
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# # Construyendo una figura

# %%
x = list(range(10))
y = x

fig = plt.figure(figsize = (5,5)) #Definir el tamaño del cuadro

plt.plot(x, y, label= "Linea azulita") #definir el eje x, y  el nombre de la línea

plt.title("Una Linea") #Evidentemente el titulo

plt.xlabel("Eje de las x")  #Asignar distinción
plt.ylabel("Ejes de las y")

plt.legend() #Que me muestre la leyenda de como se llama la linea

plt.show() #Por convención hacerlo para no afectar a los que lo usen en otro IDE

# %% [markdown]
# Podemos asignarlo a una función para no tener que rehacer la línea

# %%
x = list(range(10))
y = x

def generar_linea(eje_x, eje_y):
    fig = plt.figure(figsize = (5,5)) #Definir el tamaño del cuadro
    
    plt.plot(eje_x, eje_y, label= "Linea azulita") #definir el eje x, y  el nombre de la línea
    
    plt.title("Una Linea") #Evidentemente el titulo
    
    plt.xlabel("Eje de las x")  #Asignar distinción
    plt.ylabel("Ejes de las y")
    
    plt.legend() #Que me muestre la leyenda de como se llama la linea
    
    plt.show() #Por convención hacerlo para no afectar a los que lo usen en otro IDE

# %%
generar_linea(x, y)

# %% [markdown]
# También podemos guardar la gráfica como imagen

# %%
x = list(range(10))
y = x

fig = plt.figure(figsize = (5,5)) 

plt.plot(x, y, label= "Linea azulita") 

plt.title("Una Linea") 

plt.xlabel("Eje de las x")  
plt.ylabel("Ejes de las y")

plt.legend() 

plt.savefig("figura.png") #Aquí estarás guardando como imagen

plt.show()

# %% [markdown]
# A su vez, puedes guardarla con fondo transparente, lo cual es guay

# %%
x = list(range(10))
y = x

fig = plt.figure(figsize = (5,5)) 

plt.plot(x, y, label= "Linea azulita") 

plt.title("Una Linea") 

plt.xlabel("Eje de las x")  
plt.ylabel("Ejes de las y")

plt.legend() 

plt.savefig("figura_transparente.png", transparent= True) #Aquí estarás guardando como imagen

plt.show()

# %% [markdown]
# # Tipos de visualización

# %% [markdown]
# ## Line plot

# %%
df = pd.read_csv("datos_falsos.csv", index_col= 0)

# %%
df.head()
# Out:
#    first_name last_name                      email       gender  \
# id
# 1       Hinda   Morican    hmorican0@blinklist.com     Bigender
# 2      Marwin   McMakin  mmcmakin1@nydailynews.com         Male
# 3       Orson   Endrici        oendrici2@slate.com         Male
# 4     Sauncho  Loughman  sloughman3@soundcloud.com  Genderqueer
# 5      Darsey   Thursby           dthursby4@w3.org         Male
#
#          ip_address        date  salary
# id
# 1    140.102.89.203  09/11/2021    1323
# 2    102.95.205.140  26/08/2021    1395
# 3   203.115.109.211  30/05/2021    1393
# 4     243.214.38.13  20/03/2021    1472
# 5   241.181.212.135  03/01/2021    1291

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 337 to 658
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   email       1000 non-null   object
#  3   gender      1000 non-null   object
#  4   ip_address  1000 non-null   object
#  5   date        1000 non-null   datetime64[ns]
#  6   salary      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 62.5+ KB

# %% [markdown]
# Hay que cambiar el tipo de dato de fecha a datetime, pero... ¿por qué? lo averiguaremos con un ejemplo

# %%
x = df["date"]
y = df["salary"]

fig = plt.figure(figsize=(18,18))

plt.plot(x, y)

plt.show()

# %% [markdown]
# Como podemos ver, es ilegible, al no tener la fecha como Datetime

# %% [markdown]
# De igual manera, podemos pedir cuántos valores queremos que me traiga de los datos

# %%
valores = 50

x = df["date"] [:valores] #Con esto indico de 0 a 10
y = df["salary"] [:valores]

fig = plt.figure(figsize=(18,18))

plt.plot(x, y)

plt.show()

# %% [markdown]
# La manera de arreglarlo es organizando los datos

# %%
df["date"] = pd.to_datetime(df["date"]) #Los transformamos a datetime

df.sort_values(by="date", inplace=True)
# Out:
# C:\Users\lenny\AppData\Local\Temp\ipykernel_11356\400342523.py:1: UserWarning: Parsing '26/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"]) #Los transformamos a datetime
# C:\Users\lenny\AppData\Local\Temp\ipykernel_11356\400342523.py:1: UserWarning: Parsing '30/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"]) #Los transformamos a datetime
# C:\Users\lenny\AppData\Local\Temp\ipykernel_11356\400342523.py:1: UserWarning: Parsing '20/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"]) #Los transformamos a datetime
# ...

# %%
x = df["date"] 
y = df["salary"] 

fig = plt.figure(figsize=(18,18))

plt.plot(x, y)

plt.show()

# %%
valores = 10
x = df["date"] [:valores] 
y = df["salary"] [:valores]

fig = plt.figure(figsize=(18,9))

plt.plot(x, y)

plt.show()

# %%
# Definir fechas como indice
nuevo_df = df.set_index("date")

# Agruparlos por inicio de mes y calcular media
datos = nuevo_df.groupby(pd.Grouper(freq="MS")).agg(["mean"])
# Out:
# C:\Users\lenny\AppData\Local\Temp\ipykernel_11356\3170230394.py:7: FutureWarning: ['first_name', 'last_name', 'email', 'gender', 'ip_address'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   datos = nuevo_df.groupby(pd.Grouper(freq="MS")).agg(["mean"])

# %%
datos
# Out:
#                  salary
#                    mean
# date
# 2021-01-01  1348.307692
# 2021-02-01  1337.900000
# 2021-03-01  1354.600000
# 2021-04-01  1353.579545
# 2021-05-01  1353.075000
# 2021-06-01  1346.947368
# 2021-07-01  1357.883929
# 2021-08-01  1353.970588
# 2021-09-01  1357.771429
# 2021-10-01  1350.695652
# 2021-11-01  1337.182927
# 2021-12-01  1355.746988

# %%
plt.plot(datos)

# %%
fig = plt.figure(figsize=(18,9))

plt.plot(datos)

plt.show()

# %% [markdown]
# Al nosotros no decirle 2 valores, osea no mandarle un eje x y un eje y, por defecto matplot agarrará nuestro indice como eje Y y lo que le siga como eje X, si son más de 1 valores numericos le seguirá poniendo cuantas lineas como datos

# %%
#A continuación un ejemplo

datos["salary_2"] = datos.iloc[:, 0] + 50

# %%
datos
# Out:
#                  salary     salary_2
#                    mean
# date
# 2021-01-01  1348.307692  1398.307692
# 2021-02-01  1337.900000  1387.900000
# 2021-03-01  1354.600000  1404.600000
# 2021-04-01  1353.579545  1403.579545
# 2021-05-01  1353.075000  1403.075000
# 2021-06-01  1346.947368  1396.947368
# 2021-07-01  1357.883929  1407.883929
# 2021-08-01  1353.970588  1403.970588
# 2021-09-01  1357.771429  1407.771429
# 2021-10-01  1350.695652  1400.695652
# 2021-11-01  1337.182927  1387.182927
# 2021-12-01  1355.746988  1405.746988

# %%
fig = plt.figure(figsize=(18,9))

plt.plot(datos)

plt.show()
